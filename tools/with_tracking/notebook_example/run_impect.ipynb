# %%
import json
import sys

import pandas as pd
from pathlib import Path

# Path setup to import from the project root
project_root = Path().resolve().parent.parent.parent
sys.path.insert(0, str(project_root))

from event_synchronization.with_tracking.event_synchro_manager import EventSynchronizationManager
from event_synchronization.events_utils.impect import ImpectEvents
from skillcorner.client import SkillcornerClient


skc_client = SkillcornerClient(
    username='USERNAME',
    password='PASSWORD'
)

# %% [markdown]
# # Load data

# %%
MATCH_ID = 146134

# load Skillcorner match_data
match_data = skc_client.get_match(MATCH_ID)

# load Skillcorner tracking_data
tracking_data = skc_client.get_match_tracking_data(MATCH_ID, params={'data_version':'3'})

# load raw_impect_events
with open('/path/to/impect_events.json') as f:
    raw_impect_events = json.load(f)

# load impect_match_data
with open('/path/to/impect_match_data.json') as f:
    impect_match_data = json.load(f)

# %% [markdown]
# # Run Event Synchronization Process

# %%
# standardize events
impect_events = ImpectEvents(raw_impect_events, impect_match_data, match_data)

# apply the whole event synchronization process
report_by_event, report_by_event_type, freeze_frame_format = EventSynchronizationManager(
    tracking_data, match_data, impect_events
).apply_synchronization_process()
